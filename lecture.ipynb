# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexanderPirogovID/Machine-Learning/blob/main/lecture.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install kaggle

# %%
import pandas                          # библиотека для работы с таблицами данных
import numpy as np                     # библиотека для работы с массивами.
import cv2                             # библиотека для компьютерного зрения, используется для обработки изображений.
from io import FileIO                  # модуль для работы с файлами.
import torch                           # библиотека для создания и обучения нейронных сетей
from torch.utils.data import Dataset   # модуль для работы с наборами данных.
import torch.nn as nn                  # модуль для работы с нейронными сетями.
import torch.nn.functional as F        # модуль для работы с функциями активации и операциями в нейронных сетях
from PIL import Image

from torch.utils.data import DataLoader  # класс DataLoader для загрузки данных в наборы для обучения нейронных сетей.


# модуль для преобразования изображений в тензоры и обратно, а также для нормализации изображений и комбинирования преобразований.
from torchvision import transforms as torchvision_transforms
from torchvision.transforms import ToTensor, ToPILImage, Normalize, Compose

import matplotlib.pyplot as plt          # библиотека для визуализации данных.

# %%
import ipywidgets as widgets
import os

def get_and_store_secret(placeholder, output_secret_path):
  password_field = widgets.Password(
      description=f"Enter Key:",
      placeholder=placeholder,
      disabled=False
  )

  output = widgets.Output()

  def on_button_click(b):
    with output:
      token = password_field.value
      with open(os.path.expanduser(output_secret_path), "w") as f:
        f.write(token)
      password_field.close()
      button.close()

  button = widgets.Button(description="Save Key")
  button.on_click(on_button_click)

  display(password_field, button, output)

# %%
kaggle_user_path = os.path.expanduser("~/.cache/kaggle-user.txt")
get_and_store_secret("KAGGLE_USERNAME", kaggle_user_path)
# Out:
# Password(description='Enter Key:', placeholder='KAGGLE_USERNAME')
# Button(description='Save Key', style=ButtonStyle())
# Output()

# %%
kaggle_key_path = os.path.expanduser("~/.cache/kaggle.token")
get_and_store_secret("KAGGLE_KEY", kaggle_key_path)
# Out:
# Password(description='Enter Key:', placeholder='KAGGLE_KEY')
# Button(description='Save Key', style=ButtonStyle())
# Output()

# %%
with open(kaggle_user_path) as f:
    os.environ["KAGGLE_USERNAME"] = f.read().strip()

with open(kaggle_key_path) as f:
    os.environ["KAGGLE_KEY"] = f.read().strip()

# %%
# %pip install kagglehub[pandas-datasets]

# %%
# !kaggle datasets download -d saurabhshahane/road-traffic-accidents  -p ./data --force
# Out:
# Dataset URL: https://www.kaggle.com/datasets/saurabhshahane/road-traffic-accidents
# License(s): Attribution 4.0 International (CC BY 4.0)
# ...
#   0% 0.00/450k [00:00<?, ?B/s]
# 100% 450k/450k [00:00<00:00, 650MB/s]

# %%
# !unzip -o ./data/road-traffic-accidents.zip -d ./accidents
# Out:
# Archive:  ./data/road-traffic-accidents.zip
#   inflating: ./accidents/RTA Dataset.csv
#   inflating: ./accidents/cleaned.csv

# %%
accidents = pd.read_csv("./accidents/cleaned.csv")
accidents
# Out:
#       Age_band_of_driver Sex_of_driver   Educational_level  \
# 0                  18-30          Male   Above high school
# 1                  31-50          Male  Junior high school
# 2                  18-30          Male  Junior high school
# 3                  18-30          Male  Junior high school
# 4                  18-30          Male  Junior high school
# ...                  ...           ...                 ...
# 12311              31-50          Male             Unknown
# 12312            Unknown          Male   Elementary school
# 12313            Over 51          Male  Junior high school
# 12314              18-30        Female  Junior high school
# 12315              18-30          Male  Junior high school
#
#       Vehicle_driver_relation Driving_experience  \
# 0                    Employee              1-2yr
# 1                    Employee         Above 10yr
# 2                    Employee              1-2yr
# 3                    Employee             5-10yr
# ...

# %%
# import kagglehub
# from kagglehub import KaggleDatasetAdapter
# file_path = kagglehub.dataset_download("saurabhshahane/road-traffic-accidents")
# df = kagglehub.load_dataset(
#   KaggleDatasetAdapter.PANDAS,
#   "saurabhshahane/road-traffic-accidents",
#   file_path)
# print("First 5 records:", df.head())
# Out:
# Using Colab cache for faster access to the 'road-traffic-accidents' dataset.
# /tmp/ipython-input-4171233090.py:4: DeprecationWarning: Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.
#   df = kagglehub.load_dataset(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-4171233090.py in <cell line: 0>()
#       2 from kagglehub import KaggleDatasetAdapter
#       3 file_path = kagglehub.dataset_download("saurabhshahane/road-traffic-accidents")
# ----> 4 df = kagglehub.load_dataset(
#       5   KaggleDatasetAdapter.PANDAS,
#       6   "saurabhshahane/road-traffic-accidents",
#
# /usr/local/lib/python3.12/dist-packages/kagglehub/datasets.py in load_dataset(adapter, handle, path, pandas_kwargs, sql_query, hf_kwargs)
#     176         stacklevel=2,
#     177     )
# ...
